# %% [markdown]
# ## RNN for Skyrmion trajectories prediction

# %% [markdown]
# **Imports**

# %%
# Standard imports
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn import preprocessing

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import trackpy as tp
from tqdm import tqdm  # for progress bar

# import functions
from my_functions import *

import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM

# %% [markdown]
# **Read the data**

# %%
directory = 'Rec_EDGE_300K_1L_50MA.out'
data = pd.read_csv(directory + '/filled_trajectories.csv')
data = data.drop(data.columns[0], axis=1)
no_skyrmions = data[data['frame'] == 0].shape[0]

data
# Out:
#                 y            x  frame  particle
# 0       24.420047    61.809992    0.0       0.0
# 1       31.518261   109.009463    0.0       1.0
# 2       51.658864    41.007417    0.0       2.0
# 3       60.994689    82.173861    0.0       3.0
# 4       61.572998   129.252586    0.0       4.0
# ...           ...          ...    ...       ...
# 11995   26.838018  9158.734705  799.0      10.0
# 11996   92.153535  8909.539660  799.0      11.0
# 11997  160.675052  8812.401110  799.0      12.0
# 11998  156.663224  8600.194927  799.0      13.0
# 11999   93.779025  8679.555818  799.0      14.0
#
# [12000 rows x 4 columns]

# %%
# this function splits the data in sequences
# each sequence is n_steps long and outputs a single value, i.e. the next time frame
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %% [markdown]
# ## Experiment 1: predict next frame given n previous time steps

# %% [markdown]
# In this experiment, the aim is to predict the next frame given a series of length n of the previous time steps. We will be using a simple RNN model for this. It might be worth trying to use LSTMs as well.

# %%
# first, scale the data x and y separately as they have very different ranges

min_max_scaler_x = preprocessing.MinMaxScaler()
min_max_scaler_y = preprocessing.MinMaxScaler()

data_scaled = data.copy()

data_scaled['x'] = min_max_scaler_x.fit_transform(np.reshape(data['x'].values.astype(float), (-1, 1)))
data_scaled['y'] = min_max_scaler_y.fit_transform(np.reshape(data['y'].values.astype(float), (-1, 1)))

data_scaled
# Out:
#               y         x  frame  particle
# 0      0.065298  0.003366    0.0       0.0
# 1      0.105854  0.008537    0.0       1.0
# 2      0.220930  0.001087    0.0       2.0
# 3      0.274271  0.005597    0.0       3.0
# 4      0.277575  0.010755    0.0       4.0
# ...         ...       ...    ...       ...
# 11995  0.079113  1.000000  799.0      10.0
# 11996  0.452300  0.972699  799.0      11.0
# 11997  0.843805  0.962057  799.0      12.0
# 11998  0.820883  0.938808  799.0      13.0
# 11999  0.461588  0.947502  799.0      14.0
#
# [12000 rows x 4 columns]

# %%
# show which frames we will be working on
print('**Particles used for training**')
show_tracked(data, directory)

# format data so that it is in the format (frame, next_frame)
frames = np.array(get_frames(data_scaled))

# data in columns ['frame', 'next_frame']
df = pd.DataFrame(columns=['frame', 'next_frame'])

for i in range(1, len(frames)):
    df = df.append({'frame': frames[i-1], 'next_frame': frames[i]}, ignore_index=True)
# Out:
# **Particles used for training**
# Getting frames: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 800/800 [00:06<00:00, 122.80it/s]

# %%
# split into train and test sets
# we will use one third for testing
train_size = int(len(frames) * 0.67)
test_size = len(frames) - train_size
train, test = frames[0:train_size,:], frames[train_size:len(frames),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps = 5
# convert into input/output
X_train, y_train = split_sequences(train, n_steps)
X_test, y_test = split_sequences(test, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

# %%
# define model
model = Sequential()
model.add(SimpleRNN(128, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(SimpleRNN(512, activation='relu', return_sequences=True))
model.add(SimpleRNN(128, activation='relu'))
model.add(Dense(n_features))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=100, batch_size=10)
# Out:
# Train on 531 samples, validate on 259 samples
# Epoch 1/100
# 531/531 [==============================] - 1s 2ms/step - loss: 0.0863 - val_loss: 0.1420
# Epoch 2/100
# 531/531 [==============================] - 0s 838us/step - loss: 0.0367 - val_loss: 0.1193
# Epoch 3/100
# 531/531 [==============================] - 0s 811us/step - loss: 0.0328 - val_loss: 0.1106
# Epoch 4/100
# 531/531 [==============================] - 0s 879us/step - loss: 0.0272 - val_loss: 0.1214
# Epoch 5/100
# 531/531 [==============================] - 0s 860us/step - loss: 0.0235 - val_loss: 0.1128
# Epoch 6/100
# 531/531 [==============================] - 0s 896us/step - loss: 0.0227 - val_loss: 0.1074
# Epoch 7/100
# 531/531 [==============================] - 0s 794us/step - loss: 0.0231 - val_loss: 0.1196
# Epoch 8/100
# 531/531 [==============================] - 0s 804us/step - loss: 0.0217 - val_loss: 0.1055
# Epoch 9/100
# 531/531 [==============================] - 0s 813us/step - loss: 0.0242 - val_loss: 0.1280
# Epoch 10/100
# 531/531 [==============================] - 0s 810us/step - loss: 0.0214 - val_loss: 0.1232
# Epoch 11/100
# 531/531 [==============================] - 0s 806us/step - loss: 0.0191 - val_loss: 0.1209
# Epoch 12/100
# 531/531 [==============================] - 0s 810us/step - loss: 0.0177 - val_loss: 0.1277
# Epoch 13/100
# 531/531 [==============================] - 0s 811us/step - loss: 0.0227 - val_loss: 0.1193
# Epoch 14/100
# 531/531 [==============================] - 0s 825us/step - loss: 0.0199 - val_loss: 0.1271
# Epoch 15/100
# 531/531 [==============================] - 0s 828us/step - loss: 0.0178 - val_loss: 0.1069
# Epoch 16/100
# 531/531 [==============================] - 0s 826us/step - loss: 0.0189 - val_loss: 0.1109
# Epoch 17/100
# 531/531 [==============================] - 0s 817us/step - loss: 0.0234 - val_loss: 0.1162
# Epoch 18/100
# 531/531 [==============================] - 0s 828us/step - loss: 0.0179 - val_loss: 0.1169
# Epoch 19/100
# 531/531 [==============================] - 0s 819us/step - loss: 0.0168 - val_loss: 0.1138
# Epoch 20/100
# 531/531 [==============================] - 0s 828us/step - loss: 0.0163 - val_loss: 0.1168
# Epoch 21/100
# 531/531 [==============================] - 0s 826us/step - loss: 0.0161 - val_loss: 0.1149
# Epoch 22/100
# 531/531 [==============================] - 0s 849us/step - loss: 0.0165 - val_loss: 0.1210
# Epoch 23/100
# 531/531 [==============================] - 0s 853us/step - loss: 0.0162 - val_loss: 0.1145
# Epoch 24/100
# 531/531 [==============================] - 0s 841us/step - loss: 0.0165 - val_loss: 0.1144
# Epoch 25/100
# 531/531 [==============================] - 0s 838us/step - loss: 0.0167 - val_loss: 0.1068
# Epoch 26/100
# 531/531 [==============================] - 0s 845us/step - loss: 0.0161 - val_loss: 0.1164
# Epoch 27/100
# 531/531 [==============================] - 0s 843us/step - loss: 0.0158 - val_loss: 0.1068
# Epoch 28/100
# 531/531 [==============================] - 0s 845us/step - loss: 0.0178 - val_loss: 0.1109
# Epoch 29/100
# 531/531 [==============================] - 0s 830us/step - loss: 0.0160 - val_loss: 0.1164
# Epoch 30/100
# 531/531 [==============================] - 1s 962us/step - loss: 0.0146 - val_loss: 0.1133
# Epoch 31/100
# 531/531 [==============================] - 0s 851us/step - loss: 0.0163 - val_loss: 0.1048
# Epoch 32/100
# 531/531 [==============================] - 0s 888us/step - loss: 0.0150 - val_loss: 0.1203
# Epoch 33/100
# 531/531 [==============================] - 0s 896us/step - loss: 0.0153 - val_loss: 0.1088
# Epoch 34/100
# 531/531 [==============================] - 0s 864us/step - loss: 0.0166 - val_loss: 0.1079
# Epoch 35/100
# 531/531 [==============================] - 0s 868us/step - loss: 0.0154 - val_loss: 0.1131
# Epoch 36/100
# 531/531 [==============================] - 0s 860us/step - loss: 0.0145 - val_loss: 0.1105
# Epoch 37/100
# 531/531 [==============================] - 0s 856us/step - loss: 0.0133 - val_loss: 0.1157
# Epoch 38/100
# 531/531 [==============================] - 0s 868us/step - loss: 0.0137 - val_loss: 0.1130
# Epoch 39/100
# 531/531 [==============================] - 0s 849us/step - loss: 0.0152 - val_loss: 0.1133
# Epoch 40/100
# 531/531 [==============================] - 0s 853us/step - loss: 0.0143 - val_loss: 0.1219
# Epoch 41/100
# 531/531 [==============================] - 0s 860us/step - loss: 0.0190 - val_loss: 0.1228
# Epoch 42/100
# 531/531 [==============================] - 0s 851us/step - loss: 0.0137 - val_loss: 0.1111
# Epoch 43/100
# 531/531 [==============================] - 0s 853us/step - loss: 0.0125 - val_loss: 0.1177
# Epoch 44/100
# 531/531 [==============================] - 0s 847us/step - loss: 0.0131 - val_loss: 0.1137
# Epoch 45/100
# 531/531 [==============================] - 0s 862us/step - loss: 0.0135 - val_loss: 0.1203
# Epoch 46/100
# 531/531 [==============================] - 0s 856us/step - loss: 0.0164 - val_loss: 0.1284
# Epoch 47/100
# 531/531 [==============================] - 0s 864us/step - loss: 0.0145 - val_loss: 0.1172
# Epoch 48/100
# 531/531 [==============================] - 0s 860us/step - loss: 0.0130 - val_loss: 0.1203
# Epoch 49/100
# 531/531 [==============================] - 0s 885us/step - loss: 0.0133 - val_loss: 0.1161
# Epoch 50/100
# 531/531 [==============================] - 0s 871us/step - loss: 0.0174 - val_loss: 0.1167
# Epoch 51/100
# 531/531 [==============================] - 0s 866us/step - loss: 0.0138 - val_loss: 0.1119
# Epoch 52/100
# 531/531 [==============================] - 0s 860us/step - loss: 0.0137 - val_loss: 0.1161
# Epoch 53/100
# 531/531 [==============================] - 0s 877us/step - loss: 0.0138 - val_loss: 0.1104
# Epoch 54/100
# 531/531 [==============================] - 1s 1ms/step - loss: 0.0130 - val_loss: 0.1195
# Epoch 55/100
# 531/531 [==============================] - 1s 990us/step - loss: 0.0134 - val_loss: 0.1201
# Epoch 56/100
# 531/531 [==============================] - 0s 881us/step - loss: 0.0138 - val_loss: 0.1139
# Epoch 57/100
# 531/531 [==============================] - 0s 902us/step - loss: 0.0139 - val_loss: 0.1105
# Epoch 58/100
# 531/531 [==============================] - 0s 877us/step - loss: 0.0140 - val_loss: 0.1149
# Epoch 59/100
# 531/531 [==============================] - 0s 930us/step - loss: 0.0125 - val_loss: 0.1168
# Epoch 60/100
# 531/531 [==============================] - 0s 909us/step - loss: 0.0128 - val_loss: 0.1298
# Epoch 61/100
# 531/531 [==============================] - 0s 879us/step - loss: 0.0137 - val_loss: 0.1191
# Epoch 62/100
# 531/531 [==============================] - 0s 875us/step - loss: 0.0122 - val_loss: 0.1098
# Epoch 63/100
# 531/531 [==============================] - 0s 907us/step - loss: 0.0128 - val_loss: 0.1097
# Epoch 64/100
# 531/531 [==============================] - 0s 871us/step - loss: 0.0126 - val_loss: 0.1200
# Epoch 65/100
# 531/531 [==============================] - 0s 930us/step - loss: 0.0136 - val_loss: 0.1094
# Epoch 66/100
# 531/531 [==============================] - 0s 905us/step - loss: 0.0126 - val_loss: 0.1141
# Epoch 67/100
# 531/531 [==============================] - 0s 909us/step - loss: 0.0127 - val_loss: 0.1067
# Epoch 68/100
# 531/531 [==============================] - 0s 917us/step - loss: 0.0135 - val_loss: 0.1177
# Epoch 69/100
# 531/531 [==============================] - 1s 958us/step - loss: 0.0118 - val_loss: 0.1175
# Epoch 70/100
# 531/531 [==============================] - 1s 950us/step - loss: 0.0117 - val_loss: 0.1174
# Epoch 71/100
# 531/531 [==============================] - 0s 868us/step - loss: 0.0128 - val_loss: 0.1163
# Epoch 72/100
# 531/531 [==============================] - 1s 945us/step - loss: 0.0123 - val_loss: 0.1133
# Epoch 73/100
# 531/531 [==============================] - 0s 935us/step - loss: 0.0120 - val_loss: 0.1107
# Epoch 74/100
# 531/531 [==============================] - 0s 915us/step - loss: 0.0118 - val_loss: 0.1245
# Epoch 75/100
# 531/531 [==============================] - 0s 883us/step - loss: 0.0151 - val_loss: 0.1069
# Epoch 76/100
# 531/531 [==============================] - 0s 924us/step - loss: 0.0127 - val_loss: 0.1104
# Epoch 77/100
# 531/531 [==============================] - 0s 924us/step - loss: 0.0116 - val_loss: 0.1080
# Epoch 78/100
# 531/531 [==============================] - 0s 894us/step - loss: 0.0124 - val_loss: 0.1150
# Epoch 79/100
# 531/531 [==============================] - 0s 924us/step - loss: 0.0125 - val_loss: 0.1089
# Epoch 80/100
# 531/531 [==============================] - 0s 935us/step - loss: 0.0116 - val_loss: 0.1266
# Epoch 81/100
# 531/531 [==============================] - 1s 943us/step - loss: 0.0149 - val_loss: 0.1283
# Epoch 82/100
# 531/531 [==============================] - 0s 928us/step - loss: 0.0119 - val_loss: 0.1131
# Epoch 83/100
# 531/531 [==============================] - 0s 926us/step - loss: 0.0121 - val_loss: 0.1082
# Epoch 84/100
# 531/531 [==============================] - 0s 911us/step - loss: 0.0130 - val_loss: 0.1156
# Epoch 85/100
# 531/531 [==============================] - 0s 905us/step - loss: 0.0124 - val_loss: 0.1144
# Epoch 86/100
# 531/531 [==============================] - 0s 932us/step - loss: 0.0114 - val_loss: 0.1105
# Epoch 87/100
# 531/531 [==============================] - 1s 949us/step - loss: 0.0117 - val_loss: 0.1078
# Epoch 88/100
# 531/531 [==============================] - 0s 932us/step - loss: 0.0114 - val_loss: 0.1093
# Epoch 89/100
# 531/531 [==============================] - 0s 918us/step - loss: 0.0117 - val_loss: 0.1145
# Epoch 90/100
# 531/531 [==============================] - 0s 909us/step - loss: 0.0114 - val_loss: 0.1200
# Epoch 91/100
# 531/531 [==============================] - 0s 924us/step - loss: 0.0116 - val_loss: 0.1196
# Epoch 92/100
# 531/531 [==============================] - 0s 939us/step - loss: 0.0123 - val_loss: 0.1186
# Epoch 93/100
# 531/531 [==============================] - 1s 947us/step - loss: 0.0134 - val_loss: 0.1150
# Epoch 94/100
# 531/531 [==============================] - 0s 905us/step - loss: 0.0116 - val_loss: 0.1199
# Epoch 95/100
# 531/531 [==============================] - 0s 933us/step - loss: 0.0115 - val_loss: 0.1111
# Epoch 96/100
# 531/531 [==============================] - 0s 903us/step - loss: 0.0114 - val_loss: 0.1029
# Epoch 97/100
# 531/531 [==============================] - 0s 900us/step - loss: 0.0119 - val_loss: 0.1076
# Epoch 98/100
# 531/531 [==============================] - 0s 905us/step - loss: 0.0117 - val_loss: 0.1035
# Epoch 99/100
# 531/531 [==============================] - 0s 930us/step - loss: 0.0122 - val_loss: 0.1156
# Epoch 100/100
# 531/531 [==============================] - 0s 928us/step - loss: 0.0110 - val_loss: 0.1103

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.013823624168781417
# R2 score is 0.9755889379831347
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.15121961175029253
# R2 score is -2.328847618184767

# %%
pred_train_df = get_predictions_df(pred_train)
pred_test_df = get_predictions_df(pred_test)
# Out:
# Prediction to dataframe: 100%|█████████████████████████████████████████████████████████████████████████████████████| 531/531 [00:09<00:00, 57.34it/s]
# Prediction to dataframe: 100%|█████████████████████████████████████████████████████████████████████████████████████| 259/259 [00:04<00:00, 58.56it/s]

# %%
pred_train_unscaled = pred_train_df.copy()
pred_test_unscaled = pred_test_df.copy()

pred_train_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_train_unscaled['x'].values.astype(float), (-1, 1)))
pred_train_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_train_unscaled['y'].values.astype(float), (-1, 1)))

pred_test_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_test_unscaled['x'].values.astype(float), (-1, 1)))
pred_test_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_test_unscaled['y'].values.astype(float), (-1, 1)))

# %%
plot_prediction(data, pred_test_unscaled, pred_train_unscaled, ids=[0])

# %% [markdown]
# **Observations**

# %% [markdown]
# So far, this experiment seems not to yield very good results. This could be likely due to the fact that we are trying to use all the positions in the previous frames to predcit all the future positions and the network might not be learning a complex enough functions to model this behaviour (in particular the interaction and non-interactions between close skyrmions).
#
# Anohter reason as to why this experiment is not yielding good results could be how the data is formatted. Maybe this is not the best way of treating the data.

# %% [markdown]
# ## Experiment 2: Predict single coordinate

# %% [markdown]
# In this experiment, we are still traying to predict a single future frames, but we are focusing on a single coordinate of a single particle, insted of considering all particle and both x and y coordinates.

# %%
# the particle and coordinate we are trying to predict
particle = 0
coordinate = 'y'

coordinate_df = data[data['particle'] == particle][coordinate].reset_index(drop=True)
coordinate_df
# Out:
# 0       24.420047
# 1       22.786106
# 2       23.797221
# 3       22.500377
# 4       22.045133
#           ...
# 795    162.759434
# 796    162.037060
# 797    162.559788
# 798    165.976863
# 799    161.975156
# Name: y, Length: 800, dtype: float64

# %%
# scale the data
min_max_scaler = preprocessing.MinMaxScaler()

coordinates_scaled = coordinate_df.copy()

coordinates_scaled = min_max_scaler.fit_transform(np.reshape(coordinate_df.values.astype(float), (-1, 1)))

coordinates_scaled.shape
# Out:
# (800, 1)

# %%
# split into train and test sets
train_size = int(len(coordinates_scaled) * 0.67)
test_size = len(coordinates_scaled) - train_size
train, test = coordinates_scaled[0:train_size,:], coordinates_scaled[train_size:len(coordinates_scaled),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps = 1
# convert into input/output
X_train, y_train = split_sequences(train, n_steps)
X_test, y_test = split_sequences(test, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

# %%
# define model
model = Sequential()
model.add(SimpleRNN(128, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(SimpleRNN(512, activation='relu', return_sequences=True))
model.add(SimpleRNN(128, activation='relu'))
model.add(Dense(n_features))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=100)
# Out:
# Train on 535 samples, validate on 263 samples
# Epoch 1/100
# 535/535 [==============================] - 1s 981us/step - loss: 0.1508 - val_loss: 0.1351
# Epoch 2/100
# 535/535 [==============================] - 0s 186us/step - loss: 0.0353 - val_loss: 0.0486
# Epoch 3/100
# 535/535 [==============================] - 0s 173us/step - loss: 0.0219 - val_loss: 0.0460
# Epoch 4/100
# 535/535 [==============================] - 0s 170us/step - loss: 0.0206 - val_loss: 0.0220
# Epoch 5/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0180 - val_loss: 0.0240
# Epoch 6/100
# 535/535 [==============================] - 0s 170us/step - loss: 0.0190 - val_loss: 0.0160
# Epoch 7/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0171 - val_loss: 0.0154
# Epoch 8/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0178 - val_loss: 0.0186
# Epoch 9/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0175 - val_loss: 0.0364
# Epoch 10/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0174 - val_loss: 0.0243
# Epoch 11/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0195 - val_loss: 0.0161
# Epoch 12/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0178 - val_loss: 0.0194
# Epoch 13/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0175 - val_loss: 0.0160
# Epoch 14/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0182 - val_loss: 0.0363
# Epoch 15/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0192 - val_loss: 0.0261
# Epoch 16/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0187 - val_loss: 0.0156
# Epoch 17/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0166 - val_loss: 0.0195
# Epoch 18/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0172 - val_loss: 0.0160
# Epoch 19/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0198 - val_loss: 0.0159
# Epoch 20/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0170 - val_loss: 0.0155
# Epoch 21/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0194 - val_loss: 0.0180
# Epoch 22/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0187 - val_loss: 0.0153
# Epoch 23/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0204 - val_loss: 0.0169
# Epoch 24/100
# 535/535 [==============================] - 0s 170us/step - loss: 0.0177 - val_loss: 0.0159
# Epoch 25/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0170 - val_loss: 0.0191
# Epoch 26/100
# 535/535 [==============================] - 0s 168us/step - loss: 0.0170 - val_loss: 0.0157
# Epoch 27/100
# 535/535 [==============================] - 0s 186us/step - loss: 0.0174 - val_loss: 0.0185
# Epoch 28/100
# 535/535 [==============================] - 0s 190us/step - loss: 0.0188 - val_loss: 0.0155
# Epoch 29/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0178 - val_loss: 0.0164
# Epoch 30/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0184 - val_loss: 0.0222
# Epoch 31/100
# 535/535 [==============================] - 0s 172us/step - loss: 0.0193 - val_loss: 0.0274
# Epoch 32/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0195 - val_loss: 0.0159
# Epoch 33/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0222 - val_loss: 0.0237
# Epoch 34/100
# 535/535 [==============================] - 0s 186us/step - loss: 0.0204 - val_loss: 0.0194
# Epoch 35/100
# 535/535 [==============================] - 0s 192us/step - loss: 0.0200 - val_loss: 0.0255
# Epoch 36/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0214 - val_loss: 0.0313
# Epoch 37/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0186 - val_loss: 0.0161
# Epoch 38/100
# 535/535 [==============================] - 0s 172us/step - loss: 0.0171 - val_loss: 0.0208
# Epoch 39/100
# 535/535 [==============================] - 0s 213us/step - loss: 0.0171 - val_loss: 0.0163
# Epoch 40/100
# 535/535 [==============================] - 0s 172us/step - loss: 0.0171 - val_loss: 0.0162
# Epoch 41/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0172 - val_loss: 0.0158
# Epoch 42/100
# 535/535 [==============================] - 0s 172us/step - loss: 0.0175 - val_loss: 0.0232
# Epoch 43/100
# 535/535 [==============================] - 0s 192us/step - loss: 0.0175 - val_loss: 0.0235
# Epoch 44/100
# 535/535 [==============================] - 0s 185us/step - loss: 0.0180 - val_loss: 0.0193
# Epoch 45/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0173 - val_loss: 0.0155
# Epoch 46/100
# 535/535 [==============================] - 0s 177us/step - loss: 0.0169 - val_loss: 0.0188
# Epoch 47/100
# 535/535 [==============================] - 0s 194us/step - loss: 0.0170 - val_loss: 0.0175
# Epoch 48/100
# 535/535 [==============================] - 0s 177us/step - loss: 0.0166 - val_loss: 0.0180
# Epoch 49/100
# 535/535 [==============================] - 0s 175us/step - loss: 0.0171 - val_loss: 0.0159
# Epoch 50/100
# 535/535 [==============================] - 0s 192us/step - loss: 0.0195 - val_loss: 0.0159
# Epoch 51/100
# 535/535 [==============================] - 0s 168us/step - loss: 0.0187 - val_loss: 0.0182
# Epoch 52/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0202 - val_loss: 0.0287
# Epoch 53/100
# 535/535 [==============================] - 0s 155us/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 54/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0184 - val_loss: 0.0268
# Epoch 55/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0200 - val_loss: 0.0232
# Epoch 56/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0182 - val_loss: 0.0194
# Epoch 57/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0169 - val_loss: 0.0156
# Epoch 58/100
# 535/535 [==============================] - 0s 153us/step - loss: 0.0165 - val_loss: 0.0208
# Epoch 59/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0193 - val_loss: 0.0254
# Epoch 60/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0219 - val_loss: 0.0280
# Epoch 61/100
# 535/535 [==============================] - 0s 168us/step - loss: 0.0205 - val_loss: 0.0398
# Epoch 62/100
# 535/535 [==============================] - 0s 196us/step - loss: 0.0198 - val_loss: 0.0165
# Epoch 63/100
# 535/535 [==============================] - 0s 175us/step - loss: 0.0176 - val_loss: 0.0155
# Epoch 64/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0185 - val_loss: 0.0197
# Epoch 65/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0176 - val_loss: 0.0160
# Epoch 66/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0169 - val_loss: 0.0189
# Epoch 67/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0179 - val_loss: 0.0187
# Epoch 68/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0172 - val_loss: 0.0160
# Epoch 69/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0180 - val_loss: 0.0154
# Epoch 70/100
# 535/535 [==============================] - 0s 155us/step - loss: 0.0183 - val_loss: 0.0218
# Epoch 71/100
# 535/535 [==============================] - 0s 162us/step - loss: 0.0180 - val_loss: 0.0155
# Epoch 72/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0166 - val_loss: 0.0223
# Epoch 73/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 74/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0165 - val_loss: 0.0281
# Epoch 75/100
# 535/535 [==============================] - 0s 155us/step - loss: 0.0179 - val_loss: 0.0160
# Epoch 76/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0186 - val_loss: 0.0164
# Epoch 77/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0169 - val_loss: 0.0154
# Epoch 78/100
# 535/535 [==============================] - 0s 166us/step - loss: 0.0194 - val_loss: 0.0227
# Epoch 79/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0192 - val_loss: 0.0282
# Epoch 80/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0189 - val_loss: 0.0162
# Epoch 81/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0189 - val_loss: 0.0157
# Epoch 82/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0173 - val_loss: 0.0274
# Epoch 83/100
# 535/535 [==============================] - 0s 164us/step - loss: 0.0188 - val_loss: 0.0196
# Epoch 84/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0189 - val_loss: 0.0164
# Epoch 85/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0178 - val_loss: 0.0205
# Epoch 86/100
# 535/535 [==============================] - 0s 157us/step - loss: 0.0173 - val_loss: 0.0154
# Epoch 87/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0170 - val_loss: 0.0268
# Epoch 88/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 89/100
# 535/535 [==============================] - 0s 177us/step - loss: 0.0182 - val_loss: 0.0186
# Epoch 90/100
# 535/535 [==============================] - 0s 183us/step - loss: 0.0189 - val_loss: 0.0282
# Epoch 91/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0206 - val_loss: 0.0172
# Epoch 92/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0180 - val_loss: 0.0182
# Epoch 93/100
# 535/535 [==============================] - 0s 186us/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 94/100
# 535/535 [==============================] - 0s 185us/step - loss: 0.0170 - val_loss: 0.0155
# Epoch 95/100
# 535/535 [==============================] - 0s 158us/step - loss: 0.0179 - val_loss: 0.0168
# Epoch 96/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0169 - val_loss: 0.0155
# Epoch 97/100
# 535/535 [==============================] - 0s 192us/step - loss: 0.0195 - val_loss: 0.0154
# Epoch 98/100
# 535/535 [==============================] - 0s 179us/step - loss: 0.0168 - val_loss: 0.0155
# Epoch 99/100
# 535/535 [==============================] - 0s 160us/step - loss: 0.0173 - val_loss: 0.0154
# Epoch 100/100
# 535/535 [==============================] - 0s 185us/step - loss: 0.0168 - val_loss: 0.0228

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.023139381120466523
# R2 score is 0.9798331574159289
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.027444399855538062
# R2 score is 0.8479112437760296

# %%
pred_train_unscaled = pred_train.copy()
pred_test_unscaled = pred_test.copy()

pred_train_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_train_unscaled.astype(float), (-1, 1)))

pred_test_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_test_unscaled.astype(float), (-1, 1)))

# %%
plt.figure(figsize=(20, 10))
plt.grid(True, axis='x')
plt.xticks(np.arange(0, 801, 50))
plt.ylim(0, max(data[coordinate])+1)

plt.axvline(x=train_size, ymin=0, ymax=1, label='training vs testing', color='g')
y = np.concatenate((pred_train_unscaled, pred_test_unscaled))
x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
plt.plot(x, data[data['particle'] == particle][coordinate][n_steps:-n_steps], label='ground truth ' + str(particle), color='tab:orange')

plt.legend()

# %% [markdown]
# **Observations**

# %% [markdown]
# This experiment is yielding the expected results as we have already seen in the experiments for linear and polynomial regression that there is a close-to-linear relationship between one frame and the next and this is taking as input n = 5 frames to predict the next one, so this should in fact be quite precise.
#
# With n = 1, it seems the parformance is even better.
#
# A few questions to address are:
# 1. How many time steps in the past do we need in order to get a good prediction for the next time step?
# 2. How many time steps in the future can we predict?
# 3. How does it preform so well even without considering theinteraction with other particles? Are particles almost independent in such a simple ferromagnet?

# %% [markdown]
# ## Experiment 3: predicting multiple frames in the future

# %% [markdown]
# This is the same as experiment 2, but here we want to predict more time frames in the future.

# %%
# the particle and coordinate we are trying to predict
particle = 0
coordinate = 'y'

coordinate_df = data[data['particle'] == particle][coordinate].reset_index(drop=True)
coordinate_df
# Out:
# 0       24.420047
# 1       22.786106
# 2       23.797221
# 3       22.500377
# 4       22.045133
#           ...
# 795    162.759434
# 796    162.037060
# 797    162.559788
# 798    165.976863
# 799    161.975156
# Name: y, Length: 800, dtype: float64

# %%
# scale the data
min_max_scaler = preprocessing.MinMaxScaler()

coordinates_scaled = coordinate_df.copy()

coordinates_scaled = min_max_scaler.fit_transform(np.reshape(coordinate_df.values.astype(float), (-1, 1)))

coordinates_scaled.shape
# Out:
# (800, 1)

# %%
# split into train and test sets
train_size = int(len(coordinates_scaled) * 0.67)
test_size = len(coordinates_scaled) - train_size
train, test = coordinates_scaled[0:train_size,:], coordinates_scaled[train_size:len(coordinates_scaled),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 10, 30
# convert into input/output
X_train, y_train = split_sequence(train, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(test, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

y_train = y_train.reshape(y_train.shape[0], y_train.shape[1])
y_test = y_test.reshape(y_test.shape[0], y_test.shape[1])

# %%
# define model
model = Sequential()
model.add(SimpleRNN(32, activation='relu', return_sequences=True, input_shape=(n_steps_in, n_features)))
model.add(SimpleRNN(16, activation='relu'))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=250)
# Out:
# Train on 497 samples, validate on 225 samples
# Epoch 1/250
# 497/497 [==============================] - 0s 738us/step - loss: 0.4303 - val_loss: 0.5751
# Epoch 2/250
# 497/497 [==============================] - 0s 122us/step - loss: 0.3235 - val_loss: 0.4205
# Epoch 3/250
# 497/497 [==============================] - 0s 138us/step - loss: 0.2282 - val_loss: 0.2866
# Epoch 4/250
# 497/497 [==============================] - 0s 151us/step - loss: 0.1603 - val_loss: 0.2129
# Epoch 5/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.1107 - val_loss: 0.1353
# Epoch 6/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0805 - val_loss: 0.1041
# Epoch 7/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0638 - val_loss: 0.0931
# Epoch 8/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0539 - val_loss: 0.0700
# Epoch 9/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0465 - val_loss: 0.0570
# Epoch 10/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0410 - val_loss: 0.0540
# Epoch 11/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0409 - val_loss: 0.0585
# Epoch 12/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0415 - val_loss: 0.0556
# Epoch 13/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0403 - val_loss: 0.0676
# Epoch 14/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0408 - val_loss: 0.0747
# Epoch 15/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0409 - val_loss: 0.0585
# Epoch 16/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0399 - val_loss: 0.0517
# Epoch 17/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0401 - val_loss: 0.0727
# Epoch 18/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0406 - val_loss: 0.0682
# Epoch 19/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0415 - val_loss: 0.0668
# Epoch 20/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0390 - val_loss: 0.0610
# Epoch 21/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0389 - val_loss: 0.0646
# Epoch 22/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0386 - val_loss: 0.0559
# Epoch 23/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0385 - val_loss: 0.0481
# Epoch 24/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0393 - val_loss: 0.0631
# Epoch 25/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0386 - val_loss: 0.0459
# Epoch 26/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0396 - val_loss: 0.0665
# Epoch 27/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0395 - val_loss: 0.0578
# Epoch 28/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0384 - val_loss: 0.0520
# Epoch 29/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0391 - val_loss: 0.0625
# Epoch 30/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0386 - val_loss: 0.0580
# Epoch 31/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0384 - val_loss: 0.0496
# Epoch 32/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0384 - val_loss: 0.0627
# Epoch 33/250
# 497/497 [==============================] - 0s 100us/step - loss: 0.0398 - val_loss: 0.0494
# Epoch 34/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0382 - val_loss: 0.0567
# Epoch 35/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0396 - val_loss: 0.0429
# Epoch 36/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0407 - val_loss: 0.0617
# Epoch 37/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0382 - val_loss: 0.0510
# Epoch 38/250
# 497/497 [==============================] - 0s 130us/step - loss: 0.0380 - val_loss: 0.0676
# Epoch 39/250
# 497/497 [==============================] - 0s 138us/step - loss: 0.0389 - val_loss: 0.0511
# Epoch 40/250
# 497/497 [==============================] - ETA: 0s - loss: 0.039 - 0s 116us/step - loss: 0.0388 - val_loss: 0.0564
# Epoch 41/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0383 - val_loss: 0.0502
# Epoch 42/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0385 - val_loss: 0.0565
# Epoch 43/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0389 - val_loss: 0.0586
# Epoch 44/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0388 - val_loss: 0.0552
# Epoch 45/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0377 - val_loss: 0.0463
# Epoch 46/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0381 - val_loss: 0.0507
# Epoch 47/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0384 - val_loss: 0.0554
# Epoch 48/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0378 - val_loss: 0.0487
# Epoch 49/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0381 - val_loss: 0.0485
# Epoch 50/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0377 - val_loss: 0.0562
# Epoch 51/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0378 - val_loss: 0.0525
# Epoch 52/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0376 - val_loss: 0.0530
# Epoch 53/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0378 - val_loss: 0.0521
# Epoch 54/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0375 - val_loss: 0.0460
# Epoch 55/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0380 - val_loss: 0.0615
# Epoch 56/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0383 - val_loss: 0.0515
# Epoch 57/250
# 497/497 [==============================] - 0s 128us/step - loss: 0.0377 - val_loss: 0.0601
# Epoch 58/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0378 - val_loss: 0.0467
# Epoch 59/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0381 - val_loss: 0.0522
# Epoch 60/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0380 - val_loss: 0.0561
# Epoch 61/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0381 - val_loss: 0.0554
# Epoch 62/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0386 - val_loss: 0.0576
# Epoch 63/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0405 - val_loss: 0.0610
# Epoch 64/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0378 - val_loss: 0.0572
# Epoch 65/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0376 - val_loss: 0.0465
# Epoch 66/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0378 - val_loss: 0.0500
# Epoch 67/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0377 - val_loss: 0.0539
# Epoch 68/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0376 - val_loss: 0.0497
# Epoch 69/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0376 - val_loss: 0.0489
# Epoch 70/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0377 - val_loss: 0.0499
# Epoch 71/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0381 - val_loss: 0.0691
# Epoch 72/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0376 - val_loss: 0.0574
# Epoch 73/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0376 - val_loss: 0.0556
# Epoch 74/250
# 497/497 [==============================] - 0s 136us/step - loss: 0.0373 - val_loss: 0.0635
# Epoch 75/250
# 497/497 [==============================] - 0s 139us/step - loss: 0.0375 - val_loss: 0.0637
# Epoch 76/250
# 497/497 [==============================] - 0s 138us/step - loss: 0.0382 - val_loss: 0.0583
# Epoch 77/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0375 - val_loss: 0.0576
# Epoch 78/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0373 - val_loss: 0.0522
# Epoch 79/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0373 - val_loss: 0.0512
# Epoch 80/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0373 - val_loss: 0.0468
# Epoch 81/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0381 - val_loss: 0.0491
# Epoch 82/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0374 - val_loss: 0.0471
# Epoch 83/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0372 - val_loss: 0.0545
# Epoch 84/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0373 - val_loss: 0.0453
# Epoch 85/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0374 - val_loss: 0.0594
# Epoch 86/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0384 - val_loss: 0.0619
# Epoch 87/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0380 - val_loss: 0.0563
# Epoch 88/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0375 - val_loss: 0.0462
# Epoch 89/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0372 - val_loss: 0.0567
# Epoch 90/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0373 - val_loss: 0.0562
# Epoch 91/250
# 497/497 [==============================] - 0s 144us/step - loss: 0.0380 - val_loss: 0.0536
# Epoch 92/250
# 497/497 [==============================] - 0s 163us/step - loss: 0.0378 - val_loss: 0.0638
# Epoch 93/250
# 497/497 [==============================] - 0s 134us/step - loss: 0.0377 - val_loss: 0.0474
# Epoch 94/250
# 497/497 [==============================] - 0s 153us/step - loss: 0.0376 - val_loss: 0.0620
# Epoch 95/250
# 497/497 [==============================] - 0s 128us/step - loss: 0.0382 - val_loss: 0.0481
# Epoch 96/250
# 497/497 [==============================] - 0s 151us/step - loss: 0.0375 - val_loss: 0.0533
# Epoch 97/250
# 497/497 [==============================] - 0s 128us/step - loss: 0.0379 - val_loss: 0.0481
# Epoch 98/250
# 497/497 [==============================] - 0s 126us/step - loss: 0.0372 - val_loss: 0.0510
# Epoch 99/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0372 - val_loss: 0.0548
# Epoch 100/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0379 - val_loss: 0.0712
# Epoch 101/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0380 - val_loss: 0.0466
# Epoch 102/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0374 - val_loss: 0.0520
# Epoch 103/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0379 - val_loss: 0.0506
# Epoch 104/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0376 - val_loss: 0.0516
# Epoch 105/250
# 497/497 [==============================] - 0s 122us/step - loss: 0.0375 - val_loss: 0.0523
# Epoch 106/250
# 497/497 [==============================] - 0s 124us/step - loss: 0.0372 - val_loss: 0.0569
# Epoch 107/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0372 - val_loss: 0.0503
# Epoch 108/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0372 - val_loss: 0.0520
# Epoch 109/250
# 497/497 [==============================] - 0s 100us/step - loss: 0.0378 - val_loss: 0.0639
# Epoch 110/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0373 - val_loss: 0.0504
# Epoch 111/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0374 - val_loss: 0.0509
# Epoch 112/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0374 - val_loss: 0.0579
# Epoch 113/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0370 - val_loss: 0.0473
# Epoch 114/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0373 - val_loss: 0.0544
# Epoch 115/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0375 - val_loss: 0.0524
# Epoch 116/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0376 - val_loss: 0.0631
# Epoch 117/250
# 497/497 [==============================] - 0s 126us/step - loss: 0.0374 - val_loss: 0.0506
# Epoch 118/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0371 - val_loss: 0.0560
# Epoch 119/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0378 - val_loss: 0.0505
# Epoch 120/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0374 - val_loss: 0.0504
# Epoch 121/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0370 - val_loss: 0.0505
# Epoch 122/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0371 - val_loss: 0.0493
# Epoch 123/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0371 - val_loss: 0.0526
# Epoch 124/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0373 - val_loss: 0.0534
# Epoch 125/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0372 - val_loss: 0.0458
# Epoch 126/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0370 - val_loss: 0.0512
# Epoch 127/250
# 497/497 [==============================] - 0s 100us/step - loss: 0.0370 - val_loss: 0.0426
# Epoch 128/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0388 - val_loss: 0.0637
# Epoch 129/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0382 - val_loss: 0.0556
# Epoch 130/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0371 - val_loss: 0.0537
# Epoch 131/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0369 - val_loss: 0.0487
# Epoch 132/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0369 - val_loss: 0.0532
# Epoch 133/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0384 - val_loss: 0.0549
# Epoch 134/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0375 - val_loss: 0.0597
# Epoch 135/250
# 497/497 [==============================] - 0s 113us/step - loss: 0.0380 - val_loss: 0.0478
# Epoch 136/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0385 - val_loss: 0.0582
# Epoch 137/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0382 - val_loss: 0.0526
# Epoch 138/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0372 - val_loss: 0.0552
# Epoch 139/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0374 - val_loss: 0.0587
# Epoch 140/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0377 - val_loss: 0.0440
# Epoch 141/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0387 - val_loss: 0.0707
# Epoch 142/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0372 - val_loss: 0.0475
# Epoch 143/250
# 497/497 [==============================] - 0s 116us/step - loss: 0.0375 - val_loss: 0.0549
# Epoch 144/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0373 - val_loss: 0.0568
# Epoch 145/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0370 - val_loss: 0.0565
# Epoch 146/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0378 - val_loss: 0.0546
# Epoch 147/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0372 - val_loss: 0.0671
# Epoch 148/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0385 - val_loss: 0.0555
# Epoch 149/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0375 - val_loss: 0.0574
# Epoch 150/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0369 - val_loss: 0.0550
# Epoch 151/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0374 - val_loss: 0.0519
# Epoch 152/250
# 497/497 [==============================] - 0s 120us/step - loss: 0.0370 - val_loss: 0.0571
# Epoch 153/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0374 - val_loss: 0.0488
# Epoch 154/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0375 - val_loss: 0.0561
# Epoch 155/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0368 - val_loss: 0.0498
# Epoch 156/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0370 - val_loss: 0.0638
# Epoch 157/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0383 - val_loss: 0.0522
# Epoch 158/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0374 - val_loss: 0.0490
# Epoch 159/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0378 - val_loss: 0.0552
# Epoch 160/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0374 - val_loss: 0.0587
# Epoch 161/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0370 - val_loss: 0.0584
# Epoch 162/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0375 - val_loss: 0.0523
# Epoch 163/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0376 - val_loss: 0.0480
# Epoch 164/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0371 - val_loss: 0.0553
# Epoch 165/250
# 497/497 [==============================] - 0s 98us/step - loss: 0.0374 - val_loss: 0.0489
# Epoch 166/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0372 - val_loss: 0.0714
# Epoch 167/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0372 - val_loss: 0.0484
# Epoch 168/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0377 - val_loss: 0.0688
# Epoch 169/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0368 - val_loss: 0.0493
# Epoch 170/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0373 - val_loss: 0.0600
# Epoch 171/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0367 - val_loss: 0.0534
# Epoch 172/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0374 - val_loss: 0.0663
# Epoch 173/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0379 - val_loss: 0.0463
# Epoch 174/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0381 - val_loss: 0.0743
# Epoch 175/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0381 - val_loss: 0.0485
# Epoch 176/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0368 - val_loss: 0.0555
# Epoch 177/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0371 - val_loss: 0.0451
# Epoch 178/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0372 - val_loss: 0.0642
# Epoch 179/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0369 - val_loss: 0.0534
# Epoch 180/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0365 - val_loss: 0.0529
# Epoch 181/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0368 - val_loss: 0.0516
# Epoch 182/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0370 - val_loss: 0.0534
# Epoch 183/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0369 - val_loss: 0.0592
# Epoch 184/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0367 - val_loss: 0.0558
# Epoch 185/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0367 - val_loss: 0.0509
# Epoch 186/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0369 - val_loss: 0.0522
# Epoch 187/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0371 - val_loss: 0.0514
# Epoch 188/250
# 497/497 [==============================] - 0s 98us/step - loss: 0.0371 - val_loss: 0.0608
# Epoch 189/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0367 - val_loss: 0.0611
# Epoch 190/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0368 - val_loss: 0.0625
# Epoch 191/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0367 - val_loss: 0.0559
# Epoch 192/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0371 - val_loss: 0.0559
# Epoch 193/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0365 - val_loss: 0.0492
# Epoch 194/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0373 - val_loss: 0.0884
# Epoch 195/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0386 - val_loss: 0.0447
# Epoch 196/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0375 - val_loss: 0.0585
# Epoch 197/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0365 - val_loss: 0.0516
# Epoch 198/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0365 - val_loss: 0.0692
# Epoch 199/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0369 - val_loss: 0.0576
# Epoch 200/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0365 - val_loss: 0.0545
# Epoch 201/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0368 - val_loss: 0.0509
# Epoch 202/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0369 - val_loss: 0.0552
# Epoch 203/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0365 - val_loss: 0.0670
# Epoch 204/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0374 - val_loss: 0.0446
# Epoch 205/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0376 - val_loss: 0.0666
# Epoch 206/250
# 497/497 [==============================] - 0s 122us/step - loss: 0.0371 - val_loss: 0.0542
# Epoch 207/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0375 - val_loss: 0.0625
# Epoch 208/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0374 - val_loss: 0.0557
# Epoch 209/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0368 - val_loss: 0.0590
# Epoch 210/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0366 - val_loss: 0.0574
# Epoch 211/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0367 - val_loss: 0.0522
# Epoch 212/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0366 - val_loss: 0.0651
# Epoch 213/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0651
# Epoch 214/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0364 - val_loss: 0.0672
# Epoch 215/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0627
# Epoch 216/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0366 - val_loss: 0.0580
# Epoch 217/250
# 497/497 [==============================] - 0s 110us/step - loss: 0.0371 - val_loss: 0.0525
# Epoch 218/250
# 497/497 [==============================] - 0s 118us/step - loss: 0.0368 - val_loss: 0.0639
# Epoch 219/250
# 497/497 [==============================] - 0s 112us/step - loss: 0.0366 - val_loss: 0.0634
# Epoch 220/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0645
# Epoch 221/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0366 - val_loss: 0.0619
# Epoch 222/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0366 - val_loss: 0.0546
# Epoch 223/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0368 - val_loss: 0.0535
# Epoch 224/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0367 - val_loss: 0.0525
# Epoch 225/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0368 - val_loss: 0.0671
# Epoch 226/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0372 - val_loss: 0.0552
# Epoch 227/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0367 - val_loss: 0.0629
# Epoch 228/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0363 - val_loss: 0.0625
# Epoch 229/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0364 - val_loss: 0.0577
# Epoch 230/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0363 - val_loss: 0.0573
# Epoch 231/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0364 - val_loss: 0.0616
# Epoch 232/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0580
# Epoch 233/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0364 - val_loss: 0.0591
# Epoch 234/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0373 - val_loss: 0.0505
# Epoch 235/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0368 - val_loss: 0.0732
# Epoch 236/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0372 - val_loss: 0.0572
# Epoch 237/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0364 - val_loss: 0.0553
# Epoch 238/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0365 - val_loss: 0.0690
# Epoch 239/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0487
# Epoch 240/250
# 497/497 [==============================] - 0s 114us/step - loss: 0.0378 - val_loss: 0.0716
# Epoch 241/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0370 - val_loss: 0.0544
# Epoch 242/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0364 - val_loss: 0.0662
# Epoch 243/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0370 - val_loss: 0.0680
# Epoch 244/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0365 - val_loss: 0.0615
# Epoch 245/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0363 - val_loss: 0.0596
# Epoch 246/250
# 497/497 [==============================] - 0s 102us/step - loss: 0.0364 - val_loss: 0.0639
# Epoch 247/250
# 497/497 [==============================] - 0s 106us/step - loss: 0.0366 - val_loss: 0.0722
# Epoch 248/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0370 - val_loss: 0.0589
# Epoch 249/250
# 497/497 [==============================] - 0s 104us/step - loss: 0.0364 - val_loss: 0.0524
# Epoch 250/250
# 497/497 [==============================] - 0s 108us/step - loss: 0.0366 - val_loss: 0.0607

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.048935804468212336
# R2 score is 0.8391491509283093
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.07639660958920377
# R2 score is -0.19843002714755162

# %%
pred_train_unscaled = pred_train.copy()
pred_test_unscaled = pred_test.copy()

pred_train_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_train_unscaled.astype(float), (-1, 1))).reshape(pred_train.shape[0], -1)

pred_test_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_test_unscaled.astype(float), (-1, 1))).reshape(pred_test.shape[0], -1)

# %%
X_train_unscaled = X_train.copy()
X_test_unscaled = X_test.copy()

X_train_unscaled = min_max_scaler.inverse_transform(np.reshape(X_train.astype(float), (-1, 1))).reshape(X_train.shape[0], -1)
X_test_unscaled = min_max_scaler.inverse_transform(np.reshape(X_test.astype(float), (-1, 1))).reshape(X_test.shape[0], -1)

# %%
for i in range (0, len(X_train_unscaled), n_steps_in + n_steps_out):
    plt.figure()
    plt.grid(True, axis='x')
    plt.ylim(0, max(data[coordinate])+1)
    plt.title('Prediction on training set')

    plt.axvline(x=n_steps_in, ymin=0, ymax=1, label='first prediction', color='g')
    y = np.concatenate((X_train_unscaled[i], pred_train_unscaled[i]))
    x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

    plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
    plt.plot(x, data[data['particle'] == particle][coordinate][i:i+n_steps_in+n_steps_out], label='ground truth ' + str(particle), color='tab:orange')

    plt.legend()

# %%
for i in range (0, len(X_test_unscaled), n_steps_in + n_steps_out):
    plt.figure()
    plt.grid(True, axis='x')
    plt.ylim(0, max(data[coordinate])+1)
    plt.title('Prediction on test set')

    plt.axvline(x=n_steps_in, ymin=0, ymax=1, label='first prediction', color='g')
    y = np.concatenate((X_test_unscaled[i], pred_test_unscaled[i]))
    x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

    plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
    plt.plot(x, data[data['particle'] == particle][coordinate][train_size+i:train_size+i+n_steps_in+n_steps_out], label='ground truth ' + str(particle), color='tab:orange')

    plt.legend()

# %% [markdown]
# **Observations**

# %% [markdown]
# This experiment does not yield very good results yet. The prediction can be improved with more tweaking of the RNN architecture and maybe by using an LSTM.
#
# Some interesting questions to address are:
# 1. How well can a model trained on one coordinate perform on the other coordinate?
# 2. How well can a model trained on one particle perform on the other particle?
# 3. What happens if the model is trained on the x-coordinate? This will probably make the model too simple, hence making it not able to predict y-coorinates.
# 4. How big and small can n_steps_in and n_steps_out be?
