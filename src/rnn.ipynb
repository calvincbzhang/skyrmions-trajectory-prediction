# %% [markdown]
# ## RNN for Skyrmion trajectories prediction

# %% [markdown]
# **Imports**

# %%
# Standard imports
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn import preprocessing

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

import trackpy as tp
from tqdm import tqdm  # for progress bar

# import functions
from my_functions import *

import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **Read the data**

# %%
directory = 'Rec_EDGE_300K_1L_50MA.out'
data = pd.read_csv(directory + '/filled_trajectories.csv')
data = data.drop(data.columns[0], axis=1)
no_skyrmions = data[data['frame'] == 0].shape[0]

data
# Out:
#                 y            x  frame  particle
# 0       24.420047    61.809992    0.0       0.0
# 1       31.518261   109.009463    0.0       1.0
# 2       51.658864    41.007417    0.0       2.0
# 3       60.994689    82.173861    0.0       3.0
# 4       61.572998   129.252586    0.0       4.0
# ...           ...          ...    ...       ...
# 11995   26.838018  9158.734705  799.0      10.0
# 11996   92.153535  8909.539660  799.0      11.0
# 11997  160.675052  8812.401110  799.0      12.0
# 11998  156.663224  8600.194927  799.0      13.0
# 11999   93.779025  8679.555818  799.0      14.0
#
# [12000 rows x 4 columns]

# %%
# this function splits the data in sequences
# each sequence is n_steps long and outputs a single value, i.e. the next time frame
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix, :]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        # check if we are beyond the sequence
        if out_end_ix > len(sequence):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %% [markdown]
# ## Experiment 1: predict next frame given n previous time steps

# %% [markdown]
# In this experiment, the aim is to predict the next frame given a series of length n of the previous time steps. We will be using a simple RNN model for this. It might be worth trying to use LSTMs as well.

# %%
# first, scale the data x and y separately as they have very different ranges

min_max_scaler_x = preprocessing.MinMaxScaler()
min_max_scaler_y = preprocessing.MinMaxScaler()

data_scaled = data.copy()

data_scaled['x'] = min_max_scaler_x.fit_transform(np.reshape(data['x'].values.astype(float), (-1, 1)))
data_scaled['y'] = min_max_scaler_y.fit_transform(np.reshape(data['y'].values.astype(float), (-1, 1)))

data_scaled
# Out:
#               y         x  frame  particle
# 0      0.065298  0.003366    0.0       0.0
# 1      0.105854  0.008537    0.0       1.0
# 2      0.220930  0.001087    0.0       2.0
# 3      0.274271  0.005597    0.0       3.0
# 4      0.277575  0.010755    0.0       4.0
# ...         ...       ...    ...       ...
# 11995  0.079113  1.000000  799.0      10.0
# 11996  0.452300  0.972699  799.0      11.0
# 11997  0.843805  0.962057  799.0      12.0
# 11998  0.820883  0.938808  799.0      13.0
# 11999  0.461588  0.947502  799.0      14.0
#
# [12000 rows x 4 columns]

# %%
# show which frames we will be working on
print('**Particles used for training**')
show_tracked(data, directory)

# format data so that it is in the format (frame, next_frame)
frames = np.array(get_frames(data_scaled))

# data in columns ['frame', 'next_frame']
df = pd.DataFrame(columns=['frame', 'next_frame'])

for i in range(1, len(frames)):
    df = df.append({'frame': frames[i-1], 'next_frame': frames[i]}, ignore_index=True)
# Out:
# **Particles used for training**
# Getting frames: 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 800/800 [00:06<00:00, 118.86it/s]

# %%
# split into train and test sets
# we will use one third for testing
train_size = int(len(frames) * 0.67)
test_size = len(frames) - train_size
train, test = frames[0:train_size,:], frames[train_size:len(frames),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps = 2
# convert into input/output
X_train, y_train = split_sequences(train, n_steps)
X_test, y_test = split_sequences(test, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

# %%
# define model
model = Sequential()
model.add(SimpleRNN(64, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(n_features))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=100)
# Out:
# Train on 534 samples, validate on 262 samples
# Epoch 1/100
# 534/534 [==============================] - 0s 374us/step - loss: 0.3513 - val_loss: 0.3868
# Epoch 2/100
# 534/534 [==============================] - 0s 67us/step - loss: 0.1644 - val_loss: 0.2623
# Epoch 3/100
# 534/534 [==============================] - 0s 62us/step - loss: 0.0858 - val_loss: 0.2159
# Epoch 4/100
# 534/534 [==============================] - 0s 65us/step - loss: 0.0591 - val_loss: 0.1809
# Epoch 5/100
# 534/534 [==============================] - 0s 63us/step - loss: 0.0484 - val_loss: 0.1669
# Epoch 6/100
# 534/534 [==============================] - 0s 63us/step - loss: 0.0430 - val_loss: 0.1560
# Epoch 7/100
# 534/534 [==============================] - 0s 56us/step - loss: 0.0403 - val_loss: 0.1516
# Epoch 8/100
# 534/534 [==============================] - 0s 58us/step - loss: 0.0385 - val_loss: 0.1441
# Epoch 9/100
# 534/534 [==============================] - ETA: 0s - loss: 0.034 - 0s 52us/step - loss: 0.0370 - val_loss: 0.1420
# Epoch 10/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0362 - val_loss: 0.1334
# Epoch 11/100
# 534/534 [==============================] - 0s 52us/step - loss: 0.0349 - val_loss: 0.1312
# Epoch 12/100
# 534/534 [==============================] - 0s 52us/step - loss: 0.0339 - val_loss: 0.1279
# Epoch 13/100
# 534/534 [==============================] - 0s 48us/step - loss: 0.0329 - val_loss: 0.1247
# Epoch 14/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0320 - val_loss: 0.1230
# Epoch 15/100
# 534/534 [==============================] - 0s 56us/step - loss: 0.0311 - val_loss: 0.1194
# Epoch 16/100
# 534/534 [==============================] - 0s 61us/step - loss: 0.0303 - val_loss: 0.1156
# Epoch 17/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0295 - val_loss: 0.1169
# Epoch 18/100
# 534/534 [==============================] - 0s 52us/step - loss: 0.0287 - val_loss: 0.1135
# Epoch 19/100
# Epoch 78/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0149 - val_loss: 0.0824
# Epoch 79/100
# 534/534 [==============================] - 0s 49us/step - loss: 0.0151 - val_loss: 0.0813
# Epoch 80/100
# 534/534 [==============================] - 0s 52us/step - loss: 0.0152 - val_loss: 0.0807
# Epoch 81/100
# 534/534 [==============================] - 0s 49us/step - loss: 0.0149 - val_loss: 0.0828
# Epoch 82/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0148 - val_loss: 0.0809
# Epoch 83/100
# 534/534 [==============================] - 0s 47us/step - loss: 0.0145 - val_loss: 0.0810
# Epoch 84/100
# 534/534 [==============================] - 0s 43us/step - loss: 0.0144 - val_loss: 0.0829
# Epoch 85/100
# 534/534 [==============================] - 0s 47us/step - loss: 0.0146 - val_loss: 0.0837
# Epoch 86/100
# 534/534 [==============================] - 0s 49us/step - loss: 0.0142 - val_loss: 0.0828
# Epoch 87/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0145 - val_loss: 0.0834
# Epoch 88/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0144 - val_loss: 0.0836
# Epoch 89/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0148 - val_loss: 0.0826
# Epoch 90/100
# 534/534 [==============================] - 0s 54us/step - loss: 0.0141 - val_loss: 0.0823
# Epoch 91/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0141 - val_loss: 0.0829
# Epoch 92/100
# 534/534 [==============================] - 0s 45us/step - loss: 0.0141 - val_loss: 0.0821
# Epoch 93/100
# 534/534 [==============================] - 0s 47us/step - loss: 0.0141 - val_loss: 0.0834
# Epoch 94/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0140 - val_loss: 0.0838
# Epoch 95/100
# 534/534 [==============================] - 0s 47us/step - loss: 0.0140 - val_loss: 0.0841
# Epoch 96/100
# 534/534 [==============================] - 0s 45us/step - loss: 0.0140 - val_loss: 0.0865
# Epoch 97/100
# 534/534 [==============================] - 0s 52us/step - loss: 0.0142 - val_loss: 0.0840
# Epoch 98/100
# 534/534 [==============================] - 0s 43us/step - loss: 0.0137 - val_loss: 0.0849
# Epoch 99/100
# 534/534 [==============================] - 0s 50us/step - loss: 0.0136 - val_loss: 0.0827
# Epoch 100/100
# 534/534 [==============================] - 0s 45us/step - loss: 0.0136 - val_loss: 0.0858

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.02002944308660233
# R2 score is 0.9435140993392153
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.11973477003565855
# R2 score is -0.8080347924565389

# %%
pred_train_df = get_predictions_df(pred_train)
pred_test_df = get_predictions_df(pred_test)
# Out:
# Prediction to dataframe: 100%|█████████████████████████████████████████████████████████████████████████████████████| 534/534 [00:09<00:00, 55.92it/s]
# Prediction to dataframe: 100%|█████████████████████████████████████████████████████████████████████████████████████| 262/262 [00:04<00:00, 56.59it/s]

# %%
pred_train_unscaled = pred_train_df.copy()
pred_test_unscaled = pred_test_df.copy()

pred_train_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_train_unscaled['x'].values.astype(float), (-1, 1)))
pred_train_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_train_unscaled['y'].values.astype(float), (-1, 1)))

pred_test_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_test_unscaled['x'].values.astype(float), (-1, 1)))
pred_test_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_test_unscaled['y'].values.astype(float), (-1, 1)))

# %%
plot_prediction(data, pred_test_unscaled, pred_train_unscaled, ids=[0])

# %% [markdown]
# **Observations**

# %% [markdown]
# So far, this experiment seems not to yield very good results. This could be likely due to the fact that we are trying to use all the positions in the previous frames to predcit all the future positions and the network might not be learning a complex enough functions to model this behaviour (in particular the interaction and non-interactions between close skyrmions).
#
# Anohter reason as to why this experiment is not yielding good results could be how the data is formatted. Maybe this is not the best way of treating the data.

# %% [markdown]
# ## Experiment 2: Predict single coordinate

# %% [markdown]
# In this experiment, we are still traying to predict a single future frames, but we are focusing on a single coordinate of a single particle, insted of considering all particle and both x and y coordinates.

# %%
# the particle and coordinate we are trying to predict
particle = 0
coordinate = 'y'

coordinate_df = data[data['particle'] == particle][coordinate].reset_index(drop=True)
coordinate_df
# Out:
# 0       24.420047
# 1       22.786106
# 2       23.797221
# 3       22.500377
# 4       22.045133
#           ...
# 795    162.759434
# 796    162.037060
# 797    162.559788
# 798    165.976863
# 799    161.975156
# Name: y, Length: 800, dtype: float64

# %%
# scale the data
min_max_scaler = preprocessing.MinMaxScaler()

coordinates_scaled = coordinate_df.copy()

coordinates_scaled = min_max_scaler.fit_transform(np.reshape(coordinate_df.values.astype(float), (-1, 1)))

coordinates_scaled.shape
# Out:
# (800, 1)

# %%
# split into train and test sets
train_size = int(len(coordinates_scaled) * 0.67)
test_size = len(coordinates_scaled) - train_size
train, test = coordinates_scaled[0:train_size,:], coordinates_scaled[train_size:len(coordinates_scaled),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps = 1
# convert into input/output
X_train, y_train = split_sequences(train, n_steps)
X_test, y_test = split_sequences(test, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

# %%
# define model
model = Sequential()
model.add(SimpleRNN(16, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(n_features))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=100)
# Out:
# Train on 535 samples, validate on 263 samples
# Epoch 1/100
# 535/535 [==============================] - 0s 355us/step - loss: 0.2655 - val_loss: 0.3835
# Epoch 2/100
# 535/535 [==============================] - 0s 41us/step - loss: 0.1879 - val_loss: 0.2779
# 535/535 [==============================] - 0s 39us/step - loss: 0.0167 - val_loss: 0.0155
# Epoch 91/100
# 535/535 [==============================] - 0s 41us/step - loss: 0.0166 - val_loss: 0.0154
# Epoch 92/100
# 535/535 [==============================] - 0s 43us/step - loss: 0.0165 - val_loss: 0.0154
# Epoch 93/100
# 535/535 [==============================] - 0s 41us/step - loss: 0.0168 - val_loss: 0.0172
# Epoch 94/100
# 535/535 [==============================] - 0s 39us/step - loss: 0.0168 - val_loss: 0.0166
# Epoch 95/100
# 535/535 [==============================] - 0s 39us/step - loss: 0.0165 - val_loss: 0.0159
# Epoch 96/100
# 535/535 [==============================] - 0s 41us/step - loss: 0.0165 - val_loss: 0.0155
# Epoch 97/100
# 535/535 [==============================] - 0s 37us/step - loss: 0.0167 - val_loss: 0.0159
# Epoch 98/100
# 535/535 [==============================] - 0s 43us/step - loss: 0.0165 - val_loss: 0.0177
# Epoch 99/100
# 535/535 [==============================] - 0s 46us/step - loss: 0.0169 - val_loss: 0.0176
# Epoch 100/100
# 535/535 [==============================] - 0s 41us/step - loss: 0.0169 - val_loss: 0.0169

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.02088651053307118
# R2 score is 0.9835689162781452
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.021176126166125474
# R2 score is 0.9094512074573473

# %%
pred_train_unscaled = pred_train.copy()
pred_test_unscaled = pred_test.copy()

pred_train_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_train_unscaled.astype(float), (-1, 1)))

pred_test_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_test_unscaled.astype(float), (-1, 1)))

# %%
plt.figure(figsize=(20, 10))
plt.grid(True, axis='x')
plt.xticks(np.arange(0, 801, 50))
plt.ylim(0, max(data[coordinate])+1)

plt.axvline(x=train_size, ymin=0, ymax=1, label='training vs testing', color='g')
y = np.concatenate((pred_train_unscaled, pred_test_unscaled))
x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
plt.plot(x, data[data['particle'] == particle][coordinate][n_steps:-n_steps], label='ground truth ' + str(particle), color='tab:orange')

plt.legend()

# %% [markdown]
# **Observations**

# %% [markdown]
# This experiment is yielding the expected results as we have already seen in the experiments for linear and polynomial regression that there is a close-to-linear relationship between one frame and the next and this is taking as input n = 5 frames to predict the next one, so this should in fact be quite precise.
#
# With n = 1, it seems the parformance is even better.
#
# A few questions to address are:
# 1. How many time steps in the past do we need in order to get a good prediction for the next time step?
# 2. How many time steps in the future can we predict?
# 3. How does it preform so well even without considering theinteraction with other particles? Are particles almost independent in such a simple ferromagnet?

# %% [markdown]
# ## Experiment 3: predicting multiple frames in the future for a single coordinate

# %% [markdown]
# This is the same as experiment 2, but here we want to predict more time frames in the future.

# %%
# the particle and coordinate we are trying to predict
particle = 0
coordinate = 'y'

coordinate_df = data[data['particle'] == particle][coordinate].reset_index(drop=True)
coordinate_df
# Out:
# 0       24.420047
# 1       22.786106
# 2       23.797221
# 3       22.500377
# 4       22.045133
#           ...
# 795    162.759434
# 796    162.037060
# 797    162.559788
# 798    165.976863
# 799    161.975156
# Name: y, Length: 800, dtype: float64

# %%
# scale the data
min_max_scaler = preprocessing.MinMaxScaler()

coordinates_scaled = coordinate_df.copy()

coordinates_scaled = min_max_scaler.fit_transform(np.reshape(coordinate_df.values.astype(float), (-1, 1)))

coordinates_scaled.shape
# Out:
# (800, 1)

# %%
# split into train and test sets
train_size = int(len(coordinates_scaled) * 0.67)
test_size = len(coordinates_scaled) - train_size
train, test = coordinates_scaled[0:train_size,:], coordinates_scaled[train_size:len(coordinates_scaled),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps_in, n_steps_out = 10, 30
# convert into input/output
X_train, y_train = split_sequence(train, n_steps_in, n_steps_out)
X_test, y_test = split_sequence(test, n_steps_in, n_steps_out)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

y_train = y_train.reshape(y_train.shape[0], y_train.shape[1])
y_test = y_test.reshape(y_test.shape[0], y_test.shape[1])

# %%
# define model
model = Sequential()
model.add(SimpleRNN(32, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(Dense(n_steps_out))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=100, batch_size=10)
# Out:
# Train on 497 samples, validate on 225 samples
# Epoch 1/100
# 497/497 [==============================] - 0s 680us/step - loss: 0.3598 - val_loss: 0.3164
# Epoch 2/100
# 497/497 [==============================] - 0s 281us/step - loss: 0.0995 - val_loss: 0.0865
# Epoch 3/100
# 497/497 [==============================] - 0s 243us/step - loss: 0.0450 - val_loss: 0.0520
# Epoch 4/100
# 497/497 [==============================] - 0s 239us/step - loss: 0.0420 - val_loss: 0.0456
# Epoch 5/100
# 497/497 [==============================] - 0s 219us/step - loss: 0.0425 - val_loss: 0.0685
# Epoch 6/100
# 497/497 [==============================] - 0s 227us/step - loss: 0.0404 - val_loss: 0.0800
# Epoch 7/100
# 497/497 [==============================] - 0s 241us/step - loss: 0.0391 - val_loss: 0.0735
# Epoch 8/100
# 497/497 [==============================] - 0s 235us/step - loss: 0.0390 - val_loss: 0.0665
# Epoch 9/100
# 497/497 [==============================] - 0s 224us/step - loss: 0.0398 - val_loss: 0.0593
# Epoch 10/100
# 497/497 [==============================] - 0s 243us/step - loss: 0.0383 - val_loss: 0.0597
# Epoch 11/100
# 497/497 [==============================] - 0s 229us/step - loss: 0.0386 - val_loss: 0.0588
# Epoch 12/100
# 497/497 [==============================] - 0s 223us/step - loss: 0.0384 - val_loss: 0.0703
# Epoch 13/100
# 497/497 [==============================] - 0s 221us/step - loss: 0.0391 - val_loss: 0.0801
# Epoch 14/100
 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.05099792357558752
# R2 score is 0.8254315986794244
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.08384433256581927
# R2 score is -0.4423084565871951

# %%
pred_train_unscaled = pred_train.copy()
pred_test_unscaled = pred_test.copy()

pred_train_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_train_unscaled.astype(float), (-1, 1))).reshape(pred_train.shape[0], -1)

pred_test_unscaled = min_max_scaler.inverse_transform(np.reshape(pred_test_unscaled.astype(float), (-1, 1))).reshape(pred_test.shape[0], -1)

# %%
X_train_unscaled = X_train.copy()
X_test_unscaled = X_test.copy()

X_train_unscaled = min_max_scaler.inverse_transform(np.reshape(X_train.astype(float), (-1, 1))).reshape(X_train.shape[0], -1)
X_test_unscaled = min_max_scaler.inverse_transform(np.reshape(X_test.astype(float), (-1, 1))).reshape(X_test.shape[0], -1)

# %%
for i in range (0, len(X_train_unscaled), n_steps_in + n_steps_out):
    plt.figure()
    plt.grid(True, axis='x')
    plt.ylim(0, max(data[coordinate])+1)
    plt.title('Prediction on training set')

    plt.axvline(x=n_steps_in, ymin=0, ymax=1, label='first prediction', color='g')
    y = np.concatenate((X_train_unscaled[i], pred_train_unscaled[i]))
    x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

    plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
    plt.plot(x, data[data['particle'] == particle][coordinate][i:i+n_steps_in+n_steps_out], label='ground truth ' + str(particle), color='tab:orange')

    plt.legend()

# %%
for i in range (0, len(X_test_unscaled), n_steps_in + n_steps_out):
    plt.figure()
    plt.grid(True, axis='x')
    plt.ylim(0, max(data[coordinate])+1)
    plt.title('Prediction on test set')

    plt.axvline(x=n_steps_in, ymin=0, ymax=1, label='first prediction', color='g')
    y = np.concatenate((X_test_unscaled[i], pred_test_unscaled[i]))
    x = np.arange(y.shape[0]).reshape((y.shape[0], 1))

    plt.plot(x, y, label='prediction ' + str(particle), color='tab:blue')
    plt.plot(x, data[data['particle'] == particle][coordinate][train_size+i:train_size+i+n_steps_in+n_steps_out], label='ground truth ' + str(particle), color='tab:orange')

    plt.legend()

# %% [markdown]
# **Observations**

# %% [markdown]
# This experiment does not yield very good results yet. The prediction can be improved with more tweaking of the RNN architecture and maybe by using an LSTM.
#
# Some interesting questions to address are:
# 1. How well can a model trained on one coordinate perform on the other coordinate?
# 2. How well can a model trained on one particle perform on the other particle?
# 3. What happens if the model is trained on the x-coordinate? This will probably make the model too simple, hence making it not able to predict y-coorinates.
# 4. How big and small can n_steps_in and n_steps_out be?

# %% [markdown]
# ## Experiment 4: predict single particle

# %%
# the particle and coordinate we are trying to predict
particle = 0

coordinate_df = data[data['particle'] == particle].reset_index(drop=True)
coordinate_df
# Out:
#               y            x  frame  particle
# 0     24.420047    61.809992    0.0       0.0
# 1     22.786106    70.800099    1.0       0.0
# 2     23.797221    78.538462    2.0       0.0
# 3     22.500377    92.436819    3.0       0.0
# 4     22.045133   104.597821    4.0       0.0
# ..          ...          ...    ...       ...
# 795  162.759434  8981.526291  795.0       0.0
# 796  162.037060  8990.157367  796.0       0.0
# 797  162.559788  9007.540353  797.0       0.0
# 798  165.976863  9017.586395  798.0       0.0
# 799  161.975156  9030.630412  799.0       0.0
#
# [800 rows x 4 columns]

# %%
# first, scale the data x and y separately as they have very different ranges

min_max_scaler_x = preprocessing.MinMaxScaler()
min_max_scaler_y = preprocessing.MinMaxScaler()

data_scaled = coordinate_df.copy()

data_scaled['x'] = min_max_scaler_x.fit_transform(np.reshape(coordinate_df['x'].values.astype(float), (-1, 1)))
data_scaled['y'] = min_max_scaler_y.fit_transform(np.reshape(coordinate_df['y'].values.astype(float), (-1, 1)))

data_scaled
# Out:
#             y         x  frame  particle
# 0    0.054454  0.000000    0.0       0.0
# 1    0.044384  0.001002    1.0       0.0
# 2    0.050615  0.001865    2.0       0.0
# 3    0.042623  0.003415    3.0       0.0
# 4    0.039817  0.004771    4.0       0.0
# ..        ...       ...    ...       ...
# 795  0.907040  0.994525  795.0       0.0
# 796  0.902588  0.995487  796.0       0.0
# 797  0.905810  0.997426  797.0       0.0
# 798  0.926869  0.998546  798.0       0.0
# 799  0.902207  1.000000  799.0       0.0
#
# [800 rows x 4 columns]

# %%
# show which frames we will be working on
print('**Particles used for training**')
show_tracked(coordinate_df, directory)

# format data so that it is in the format (frame, next_frame)
frames = np.array(get_frames(data_scaled))

# data in columns ['frame', 'next_frame']
df = pd.DataFrame(columns=['frame', 'next_frame'])

for i in range(1, len(frames)):
    df = df.append({'frame': frames[i-1], 'next_frame': frames[i]}, ignore_index=True)
# Out:
# **Particles used for training**
# Getting frames: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 1157.49it/s]

# %%
# split into train and test sets
# we will use one third for testing
train_size = int(len(frames) * 0.67)
test_size = len(frames) - train_size
train, test = frames[0:train_size,:], frames[train_size:len(frames),:]
print(f'Train length: {len(train)}')
print(f'Test length: {len(test)}')
# Out:
# Train length: 536
# Test length: 264

# %%
# choose a number of time steps
n_steps = 1
# convert into input/output
X_train, y_train = split_sequences(train, n_steps)
X_test, y_test = split_sequences(test, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X_train.shape[2]

# %%
# define model
model = Sequential()
model.add(SimpleRNN(16, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(n_features))
model.compile(optimizer='adam', loss='mae')

# %%
# fit model
history = model.fit(X_train, y_train, validation_data = (X_test,y_test), epochs=250)
# Out:
# Train on 535 samples, validate on 263 samples
# Epoch 1/250
# 535/535 [==============================] - ETA: 2s - loss: 0.375 - 0s 349us/step - loss: 0.3495 - val_loss: 0.5358
# Epoch 2/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.2673 - val_loss: 0.3900
# Epoch 3/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.1942 - val_loss: 0.2643
# Epoch 4/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.1204 - val_loss: 0.1395
# Epoch 5/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0672 - val_loss: 0.0837
# Epoch 6/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0552 - val_loss: 0.0691
# Epoch 7/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0478 - val_loss: 0.0557
# Epoch 8/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0443 - val_loss: 0.0519
# Epoch 9/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0430 - val_loss: 0.0507
# Epoch 10/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0418 - val_loss: 0.0488
# Epoch 11/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0407 - val_loss: 0.0474
# Epoch 12/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0395 - val_loss: 0.0463
# Epoch 13/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0386 - val_loss: 0.0456
# Epoch 14/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0376 - val_loss: 0.0447
# Epoch 15/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0367 - val_loss: 0.0437
# Epoch 16/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0358 - val_loss: 0.0419
# Epoch 17/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0350 - val_loss: 0.0419
# Epoch 18/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0341 - val_loss: 0.0409
# Epoch 19/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0332 - val_loss: 0.0402
# Epoch 20/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0323 - val_loss: 0.0387
# Epoch 21/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0315 - val_loss: 0.0384
# Epoch 22/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0306 - val_loss: 0.0373
# Epoch 23/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0298 - val_loss: 0.0358
# Epoch 24/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0294 - val_loss: 0.0350
# Epoch 25/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0284 - val_loss: 0.0338
# Epoch 26/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0274 - val_loss: 0.0343
# Epoch 27/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0266 - val_loss: 0.0326
# Epoch 28/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0259 - val_loss: 0.0322
# Epoch 29/250
# 535/535 [==============================] - 0s 54us/step - loss: 0.0248 - val_loss: 0.0312
# Epoch 30/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0240 - val_loss: 0.0314
# Epoch 31/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0232 - val_loss: 0.0291
# Epoch 32/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0223 - val_loss: 0.0298
# Epoch 33/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0215 - val_loss: 0.0270
# Epoch 34/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0207 - val_loss: 0.0271
# Epoch 35/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0199 - val_loss: 0.0258
# Epoch 36/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0190 - val_loss: 0.0245
# Epoch 37/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0183 - val_loss: 0.0244
# Epoch 38/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0174 - val_loss: 0.0223
# Epoch 39/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0166 - val_loss: 0.0220
# Epoch 40/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0159 - val_loss: 0.0204
# Epoch 41/250
# 535/535 [==============================] - 0s 38us/step - loss: 0.0151 - val_loss: 0.0204
# Epoch 42/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0143 - val_loss: 0.0196
# Epoch 43/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0138 - val_loss: 0.0173
# Epoch 44/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0133 - val_loss: 0.0163
# Epoch 45/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0124 - val_loss: 0.0173
# Epoch 46/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0120 - val_loss: 0.0160
# Epoch 47/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0115 - val_loss: 0.0156
# Epoch 48/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0112 - val_loss: 0.0158
# Epoch 49/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0108 - val_loss: 0.0130
# Epoch 50/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0104 - val_loss: 0.0135
# Epoch 51/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0101 - val_loss: 0.0142
# Epoch 52/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0098 - val_loss: 0.0118
# Epoch 53/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0096 - val_loss: 0.0125
# Epoch 54/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0094 - val_loss: 0.0121
# Epoch 55/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 56/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0093 - val_loss: 0.0112
# Epoch 57/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0090 - val_loss: 0.0102
# Epoch 58/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0090 - val_loss: 0.0112
# Epoch 59/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0090 - val_loss: 0.0101
# Epoch 60/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0089 - val_loss: 0.0100
# Epoch 61/250
# 535/535 [==============================] - 0s 36us/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 62/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 63/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0089 - val_loss: 0.0096
# Epoch 64/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 65/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0088 - val_loss: 0.0117
# Epoch 66/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 67/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 68/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0098
# Epoch 69/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0089 - val_loss: 0.0101
# Epoch 70/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0088 - val_loss: 0.0100
# Epoch 71/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0087 - val_loss: 0.0108
# Epoch 72/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0096
# Epoch 73/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 74/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0087 - val_loss: 0.0089
# Epoch 75/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0087 - val_loss: 0.0095
# Epoch 76/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0084
# Epoch 77/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 78/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0085 - val_loss: 0.0081
# Epoch 79/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 80/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0091 - val_loss: 0.0113
# Epoch 81/250
# 535/535 [==============================] - 0s 45us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 82/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0087 - val_loss: 0.0083
# Epoch 83/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 84/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0084
# Epoch 85/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0112
# Epoch 86/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0087 - val_loss: 0.0083
# Epoch 87/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 88/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0087 - val_loss: 0.0083
# Epoch 89/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0091 - val_loss: 0.0079
# Epoch 90/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0087 - val_loss: 0.0082
# Epoch 91/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0097
# Epoch 92/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 93/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0101
# Epoch 94/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0091 - val_loss: 0.0088
# Epoch 95/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0094
# Epoch 96/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 97/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0096
# Epoch 98/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0094
# Epoch 99/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0091
# Epoch 100/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 101/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 102/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 103/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 104/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0091 - val_loss: 0.0082
# Epoch 105/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0089 - val_loss: 0.0081
# Epoch 106/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 107/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0100
# Epoch 108/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 109/250
# 535/535 [==============================] - ETA: 0s - loss: 0.007 - 0s 36us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 110/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 111/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 112/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 113/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0103
# Epoch 114/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0090 - val_loss: 0.0080
# Epoch 115/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 116/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 117/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 118/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 119/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 120/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 121/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 122/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 123/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 124/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 125/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 126/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0088
# Epoch 127/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 128/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 129/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0089 - val_loss: 0.0084
# Epoch 130/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0088 - val_loss: 0.0095
# Epoch 131/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 132/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 133/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 134/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0079
# Epoch 135/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 136/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0087 - val_loss: 0.0107
# Epoch 137/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 138/250
# 535/535 [==============================] - 0s 36us/step - loss: 0.0087 - val_loss: 0.0097
# Epoch 139/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0093 - val_loss: 0.0094
# Epoch 140/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0089 - val_loss: 0.0098
# Epoch 141/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 142/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 143/250
# 535/535 [==============================] - 0s 38us/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 144/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 145/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 146/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 147/250
# 535/535 [==============================] - 0s 44us/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 148/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 149/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 150/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0090
# Epoch 151/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 152/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 153/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 154/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 155/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 156/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 157/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 158/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 159/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 160/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 161/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 162/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 163/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 164/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 165/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 166/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 167/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 168/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 169/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0094
# Epoch 170/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 171/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 172/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 173/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0082
# Epoch 174/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 175/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 176/250
# 535/535 [==============================] - 0s 43us/step - loss: 0.0089 - val_loss: 0.0104
# Epoch 177/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0092 - val_loss: 0.0081
# Epoch 178/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0084 - val_loss: 0.0082
# Epoch 179/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 180/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0084 - val_loss: 0.0081
# Epoch 181/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0081
# Epoch 182/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0087 - val_loss: 0.0086
# Epoch 183/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 184/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 185/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0084 - val_loss: 0.0087
# Epoch 186/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0084 - val_loss: 0.0087
# Epoch 187/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 188/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 189/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 190/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 191/250
# 535/535 [==============================] - 0s 38us/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 192/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0086
# Epoch 193/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 194/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 195/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 196/250
# 535/535 [==============================] - 0s 32us/step - loss: 0.0084 - val_loss: 0.0081
# Epoch 197/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 198/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 199/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 200/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 201/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0107
# Epoch 202/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 203/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 204/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0087 - val_loss: 0.0105
# Epoch 205/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0088 - val_loss: 0.0081
# Epoch 206/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 207/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0091
# Epoch 208/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 209/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0089 - val_loss: 0.0082
# Epoch 210/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 211/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 212/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 213/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0099
# Epoch 214/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0083
# Epoch 215/250
# 535/535 [==============================] - 0s 38us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 216/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 217/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 218/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0084 - val_loss: 0.0085
# Epoch 219/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 220/250
# 535/535 [==============================] - 0s 36us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 221/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0095
# Epoch 222/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0084 - val_loss: 0.0079
# Epoch 223/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0083 - val_loss: 0.0086
# Epoch 224/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0084 - val_loss: 0.0080
# Epoch 225/250
# 535/535 [==============================] - 0s 36us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 226/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 227/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0087 - val_loss: 0.0084
# Epoch 228/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0080
# Epoch 229/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0089
# Epoch 230/250
# 535/535 [==============================] - 0s 36us/step - loss: 0.0087 - val_loss: 0.0098
# Epoch 231/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0084 - val_loss: 0.0093
# Epoch 232/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 233/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 234/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0100
# Epoch 235/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0080
# Epoch 236/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0088 - val_loss: 0.0079
# Epoch 237/250
# 535/535 [==============================] - 0s 34us/step - loss: 0.0086 - val_loss: 0.0081
# Epoch 238/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 239/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0087 - val_loss: 0.0108
# Epoch 240/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0084
# Epoch 241/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 242/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 243/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0083
# Epoch 244/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0084 - val_loss: 0.0093
# Epoch 245/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0085 - val_loss: 0.0079
# Epoch 246/250
# 535/535 [==============================] - 0s 35us/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 247/250
# 535/535 [==============================] - 0s 41us/step - loss: 0.0088 - val_loss: 0.0083
# Epoch 248/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 249/250
# 535/535 [==============================] - 0s 39us/step - loss: 0.0088 - val_loss: 0.0080
# Epoch 250/250
# 535/535 [==============================] - 0s 37us/step - loss: 0.0088 - val_loss: 0.0096

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %%
print('The model performance for X_train')
pred_train = evaluate(X_train, y_train, model)
print('The model performance for X_test')
pred_test = evaluate(X_test, y_test, model)
# Out:
# The model performance for X_train
# --------------------------------------
# RMSE is 0.014844591666828343
# R2 score is 0.9917030967308791
#
#
# The model performance for X_test
# --------------------------------------
# RMSE is 0.016230011240181724
# R2 score is 0.9468411336364926

# %%
pred_train_df = get_predictions_df(pred_train)
pred_test_df = get_predictions_df(pred_test)
# Out:
# Prediction to dataframe: 100%|████████████████████████████████████████████████████████████████████████████████████| 535/535 [00:00<00:00, 812.03it/s]
# Prediction to dataframe: 100%|████████████████████████████████████████████████████████████████████████████████████| 263/263 [00:00<00:00, 748.06it/s]

# %%
pred_train_unscaled = pred_train_df.copy()
pred_test_unscaled = pred_test_df.copy()

pred_train_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_train_unscaled['x'].values.astype(float), (-1, 1)))
pred_train_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_train_unscaled['y'].values.astype(float), (-1, 1)))

pred_test_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_test_unscaled['x'].values.astype(float), (-1, 1)))
pred_test_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_test_unscaled['y'].values.astype(float), (-1, 1)))

# %%
plot_prediction(data, pred_test_unscaled, pred_train_unscaled, ids=[0])

# %%
# the particle and coordinate we are trying to predict
particle = 6

coordinate_df = data[data['particle'] == particle].reset_index(drop=True)
coordinate_df
# Out:
#              y            x  frame  particle
# 0    90.910237    99.071842    0.0       6.0
# 1    90.576910   108.093601    1.0       6.0
# 2    98.517045   120.129582    2.0       6.0
# 3    98.201415   130.673702    3.0       6.0
# 4    99.545947   142.724476    4.0       6.0
# ..         ...          ...    ...       ...
# 795  31.174472  8812.877446  795.0       6.0
# 796  32.350188  8820.465462  796.0       6.0
# 797  34.471482  8824.454910  797.0       6.0
# 798  28.888634  8842.468691  798.0       6.0
# 799  32.421220  8844.332414  799.0       6.0
#
# [800 rows x 4 columns]

# %%
# first, scale the data x and y separately as they have very different ranges

min_max_scaler_x = preprocessing.MinMaxScaler()
min_max_scaler_y = preprocessing.MinMaxScaler()

data_scaled = coordinate_df.copy()

data_scaled['x'] = min_max_scaler_x.fit_transform(np.reshape(coordinate_df['x'].values.astype(float), (-1, 1)))
data_scaled['y'] = min_max_scaler_y.fit_transform(np.reshape(coordinate_df['y'].values.astype(float), (-1, 1)))

data_scaled
# Out:
#             y         x  frame  particle
# 0    0.599412  0.000000    0.0       6.0
# 1    0.596555  0.001032    1.0       6.0
# 2    0.664606  0.002408    2.0       6.0
# 3    0.661901  0.003614    3.0       6.0
# 4    0.673424  0.004992    4.0       6.0
# ..        ...       ...    ...       ...
# 795  0.087448  0.996403  795.0       6.0
# 796  0.097525  0.997271  796.0       6.0
# 797  0.115705  0.997727  797.0       6.0
# 798  0.067858  0.999787  798.0       6.0
# 799  0.098134  1.000000  799.0       6.0
#
# [800 rows x 4 columns]

# %%
# show which frames we will be working on
print('**Particles used for training**')
show_tracked(coordinate_df, directory)

# format data so that it is in the format (frame, next_frame)
frames = np.array(get_frames(data_scaled))

# data in columns ['frame', 'next_frame']
df = pd.DataFrame(columns=['frame', 'next_frame'])

for i in range(1, len(frames)):
    df = df.append({'frame': frames[i-1], 'next_frame': frames[i]}, ignore_index=True)
# Out:
# **Particles used for training**
# Getting frames: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 800/800 [00:00<00:00, 1127.13it/s]

# %%
# choose a number of time steps
n_steps = 1
# convert into input/output
X, y = split_sequences(frames, n_steps)
# the dataset knows the number of features, e.g. 2
n_features = X.shape[2]

# %%
pred = evaluate(X, y, model)
# Out:
# --------------------------------------
# RMSE is 0.09113084209527031
# R2 score is 0.8735426579777403

# %%
pred_df = get_predictions_df(pred)
# Out:
# Prediction to dataframe: 100%|████████████████████████████████████████████████████████████████████████████████████| 799/799 [00:01<00:00, 756.85it/s]

# %%
pred_df['particle'] = particle

# %%
pred_unscaled = pred_df.copy()

pred_unscaled['x'] = min_max_scaler_x.inverse_transform(np.reshape(pred_unscaled['x'].values.astype(float), (-1, 1)))
pred_unscaled['y'] = min_max_scaler_y.inverse_transform(np.reshape(pred_unscaled['y'].values.astype(float), (-1, 1)))

# %%
plot_prediction(data, pred_unscaled, ids=[particle])
